# %% [markdown]
# # Анализ данных на Python
#
# ## Библиотека `Pandas`
# #### <i>Малкова Ксения, Преподаватель ФКН НИУ ВШЭ, kemalkova@hse.ru</i>

# %% [markdown]
# ### Практика

# %% [markdown]
# Работаем с датасетом [Student Alcohol Consumption](https://www.kaggle.com/datasets/uciml/student-alcohol-consumption). Он содержит информацию о потреблении алкоголя студентами в Португалии и был собран для анализа взаимосвязи между социально-экономическими факторами и потреблением алкоголя среди студентов.
#
# **Что к чему:**
# 1. **`school`**: Школа, в которой учится студент ("GP" — Gabriel Pereira, "MS" — Mousinho da Silveira)
# 2. **`sex`**: Пол студента ("F" — женский, "M" — мужской)
# 3. **`age`**: Возраст студента
# 4. **`address`**: Место проживания ("U" — городской, "R" — сельский)
# 5. **`famsize`**: Размер семьи ("LE3" — меньше или равно 3 людей в семье, "GT3" — больше 3)
# 6. **`Pstatus`**: Статус родителей ("T" — живут вместе, "A" — раздельно)
# 7. **`Medu`**: Уровень образования матери (0 - неизвестно, 1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)
# 8. **`Fedu`**: Уровень образования отца (same)
# 9. **`Mjob`**: Работа матери
# 10. **`Fjob`**: Работа отца (same)
# 11. **`traveltime`**: Время на дорогу до школы (1 - <15 мин., 2 - 15-30 мин., 3 - 30 мин. - 1 час, или 4 - >1 часа)
# 12. **`studytime`**: Время, затрачиваемое на учебу за неделю (1 - <2 часов, 2 - 2-5 часа, 3 - 5-10 часов, или 4 - >10 часов)
# 13. **`failures`**: Количество заваленных предметов ($n$ если $1 \leq n \leq 3$, и 4, если $n \geq 4$)
# 14. **`higher`** - Хочет ли получать высшее образование
# 15. **`internet`** - Есть ли интернет дома
# 16. **`romantic`** - Есть ли вторая половинка
# 17. **`famrel`** - Отношения с семьей (от 1 - очень плохие до 5 - отличные)
# 18. **`freetime`** - Свободное время вне школы (от 1 - очень мало до 5 - очень много)
# 19. **`Dalc`** - Частота употребления алкоголя в будние дни (от 1 - очень мало до 5 - очень много)
# 20. **`Walc`** - Частота употребления алкоголя в выходные дни (от 1 - очень мало до 5 - очень много)
# 21. **`health`** - Оценка состояния здоровья (от 1 - очень плохое до 5 - очень хорошее)
# 22. **`absences`** - Количество пропущенных занятий (numeric: from 0 to 93)
# 23. **`G1*`**: Оценка за первый квартал (от 0 до 20).
# 24. **`G2`**: Оценка за второй квартал (от 0 до 20).
# 25. **`G3`**: Оценка за год (от 0 до 20, итоговая оценка).
#
# *В Португалии используется 20-балльная система оценок, где 0 является самым низким баллом, а 20 — самым высоким. Обычно в образовательных учреждениях Португалии оценка 10 считается проходным баллом, а все, что выше, отражает степень успеваемости студента.

# %% [markdown]
# ### Этап 1. Разминка

# %% [markdown]
# 0. Считайте датафрейм по этой ссылке:
# https://raw.githubusercontent.com/ksumarshmallow/Data-Analysis-Media-24/main/Seminars/Sem1/data/student-mat.csv
#
# (используйте библиотеку `Pandas`)

# %%
# ваш код
import pandas as pd
data = pd.read_csv("https://raw.githubusercontent.com/ksumarshmallow/Data-Analysis-Media-24/main/Seminars/Sem1/data/student-mat.csv")

# %% [markdown]
# 1. Выведите 10 первых наблюдений

# %%
# ваш код
data.head(10)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1   at_home     other
# 2     GP   F   15       U     LE3       T     1     1   at_home     other
# 3     GP   F   15       U     GT3       T     4     2    health  services
# 4     GP   F   16       U     GT3       T     3     3     other     other
# 5     GP   M   16       U     LE3       T     4     3  services     other
# 6     GP   M   16       U     LE3       T     2     2     other     other
# 7     GP   F   17       U     GT3       A     4     4     other   teacher
# 8     GP   M   15       U     LE3       A     3     2  services     other
# 9     GP   M   15       U     GT3       T     3     4     other     other
#
#    ...  romantic  famrel  freetime Dalc Walc health  absences  G1  G2  G3
# 0  ...        no       4         3    1    1      3         6   5   6   6
# 1  ...        no       5         3    1    1      3         4   5   5   6
# 2  ...        no       4         3    2    3      3        10   7   8  10
# 3  ...       yes       3         2    1    1      5         2  15  14  15
# 4  ...        no       4         3    1    2      5         4   6  10  10
# 5  ...        no       5         4    1    2      5        10  15  15  15
# 6  ...        no       4         4    1    1      3         0  12  12  11
# 7  ...        no       4         1    1    1      1         6   6   5   6
# 8  ...        no       4         2    1    1      1         0  16  18  19
# 9  ...        no       5         5    1    1      5         0  14  15  15
#
# [10 rows x 25 columns]

# %% [markdown]
# 2. Выведите 15 последних наблюдений

# %%
# ваш код
data.tail(15)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 380     MS   M   18       U     GT3       T     4     4   teacher   teacher
# 381     MS   M   18       R     GT3       T     2     1     other     other
# 382     MS   M   17       U     GT3       T     2     3     other  services
# 383     MS   M   19       R     GT3       T     1     1     other  services
# 384     MS   M   18       R     GT3       T     4     2     other     other
# 385     MS   F   18       R     GT3       T     2     2   at_home     other
# 386     MS   F   18       R     GT3       T     4     4   teacher   at_home
# 387     MS   F   19       R     GT3       T     2     3  services     other
# 388     MS   F   18       U     LE3       T     3     1   teacher  services
# 389     MS   F   18       U     GT3       T     1     1     other     other
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ...  romantic  famrel  freetime Dalc Walc health  absences  G1  G2  G3
# 380  ...        no       3         2    1    4      2         4  15  14  14
# 381  ...       yes       4         4    1    3      5         5   7   6   7
# 382  ...        no       4         4    1    1      3         2  11  11  10
# 383  ...        no       4         3    1    3      5         0   6   5   0
# 384  ...        no       5         4    4    3      3        14   6   5   5
# 385  ...        no       5         3    1    3      4         2  10   9  10
# 386  ...       yes       4         4    2    2      5         7   6   5   6
# 387  ...        no       5         4    1    2      5         0   7   5   0
# 388  ...        no       4         3    1    1      1         0   7   9   8
# 389  ...        no       1         1    1    1      5         0   6   5   0
# 390  ...        no       5         5    4    5      4        11   9   9   9
# 391  ...        no       2         4    3    4      2         3  14  16  16
# 392  ...        no       5         5    3    3      3         3  10   8   7
# 393  ...        no       4         4    3    4      5         0  11  12  10
# 394  ...        no       3         2    3    3      5         5   8   9   9
#
# [15 rows x 25 columns]

# %% [markdown]
# 3. Выведите количество ячеек в датафрейме

# %%
# ваш код
data.size
# Out:
# 9875

# %% [markdown]
# 4. Выведите названия столбцов датафрейма

# %%
# ваш код
data.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'traveltime', 'studytime', 'failures', 'higher',
#        'internet', 'romantic', 'famrel', 'freetime', 'Dalc', 'Walc', 'health',
#        'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %% [markdown]
# 5. Выведите общую информацию о датафрейме

# %%
# ваш код
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 25 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  traveltime  395 non-null    int64
#  11  studytime   395 non-null    int64
#  12  failures    395 non-null    int64
#  13  higher      395 non-null    object
#  14  internet    395 non-null    object
#  15  romantic    395 non-null    object
#  16  famrel      395 non-null    int64
#  17  freetime    395 non-null    int64
#  18  Dalc        395 non-null    int64
#  19  Walc        395 non-null    int64
#  20  health      395 non-null    int64
#  21  absences    395 non-null    int64
#  22  G1          395 non-null    int64
#  23  G2          395 non-null    int64
#  24  G3          395 non-null    int64
# dtypes: int64(15), object(10)
# memory usage: 77.3+ KB

# %% [markdown]
# ### Этап 2. Приступаем к работе

# %% [markdown]
# 1. Выведите столбец **`age`**

# %%
data['age']
# Out:
# 0      18
# 1      17
# 2      15
# 3      15
# 4      16
#        ..
# 390    20
# 391    17
# 392    21
# 393    18
# 394    19
# Name: age, Length: 395, dtype: int64

# %% [markdown]
# 2. Выведите столбцы **`Medu`** и **`Mjob`**

# %%
data[['Medu', 'Mjob']]
# Out:
#      Medu      Mjob
# 0       4   at_home
# 1       1   at_home
# 2       1   at_home
# 3       4    health
# 4       3     other
# ..    ...       ...
# 390     2  services
# 391     3  services
# 392     1     other
# 393     3  services
# 394     1     other
#
# [395 rows x 2 columns]

# %% [markdown]
# 3. Выведите наблюдения со 145 по 189 строку (по всем столбцам)

# %%
# ваш код
data.iloc[145:189]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 145     GP   F   15       U     GT3       T     1     1     other  services
# 146     GP   F   15       U     GT3       T     3     2    health  services
# 147     GP   F   15       U     GT3       T     1     2   at_home     other
# 148     GP   M   16       U     GT3       T     4     4   teacher   teacher
# 149     GP   M   15       U     LE3       A     2     1  services     other
# 150     GP   M   18       U     LE3       T     1     1     other     other
# 151     GP   M   16       U     LE3       T     2     1   at_home     other
# 152     GP   F   15       R     GT3       T     3     3  services  services
# 153     GP   M   19       U     GT3       T     3     2  services   at_home
# 154     GP   F   17       U     GT3       T     4     4     other   teacher
# 155     GP   M   15       R     GT3       T     2     3   at_home  services
# 156     GP   M   17       R     LE3       T     1     2     other     other
# 157     GP   F   18       R     GT3       T     1     1   at_home     other
# 158     GP   M   16       R     GT3       T     2     2   at_home     other
# 159     GP   M   16       U     GT3       T     3     3     other  services
# 160     GP   M   17       R     LE3       T     2     1   at_home     other
# 161     GP   M   15       R     GT3       T     3     2     other     other
# 162     GP   M   16       U     LE3       T     1     2     other     other
# 163     GP   M   17       U     GT3       T     1     3   at_home  services
# 164     GP   M   17       R     LE3       T     1     1     other  services
# 165     GP   M   16       U     GT3       T     3     2  services  services
# 166     GP   M   16       U     GT3       T     2     2     other     other
# 167     GP   F   16       U     GT3       T     4     2    health  services
# 168     GP   F   16       U     GT3       T     2     2     other     other
# 169     GP   F   16       U     GT3       T     4     4    health    health
# 170     GP   M   16       U     GT3       T     3     4     other     other
# 171     GP   M   16       U     GT3       T     1     0     other     other
# 172     GP   M   17       U     LE3       T     4     4   teacher     other
# 173     GP   F   16       U     GT3       T     1     3   at_home  services
# 174     GP   F   16       U     LE3       T     3     3     other     other
# 175     GP   M   17       U     LE3       T     4     3   teacher     other
# 176     GP   F   16       U     GT3       T     2     2  services     other
# 177     GP   M   17       U     GT3       T     3     3     other     other
# 178     GP   M   16       R     GT3       T     4     2   teacher  services
# 179     GP   M   17       U     GT3       T     4     3     other     other
# 180     GP   M   16       U     GT3       T     4     3   teacher     other
# 181     GP   M   16       U     GT3       T     3     3  services     other
# 182     GP   F   17       U     GT3       T     2     4  services  services
# 183     GP   F   17       U     LE3       T     3     3     other     other
# 184     GP   F   16       U     GT3       T     3     2     other     other
# 185     GP   M   17       U     GT3       T     3     3  services  services
# 186     GP   M   16       U     GT3       T     1     2  services  services
# 187     GP   M   16       U     LE3       T     2     1     other     other
# 188     GP   F   17       U     GT3       A     3     3    health     other
#
#      ...  romantic  famrel  freetime Dalc Walc health  absences  G1  G2  G3
# 145  ...        no       4         4    1    2      5         0   8  11  11
# 146  ...        no       3         3    1    1      3         0   6   7   0
# 147  ...        no       4         3    1    1      5         2  10  11  11
# 148  ...       yes       3         3    2    1      5         0   7   6   0
# 149  ...        no       4         5    2    5      5         0   8   9  10
# 150  ...       yes       2         3    2    5      4         0   6   5   0
# 151  ...       yes       4         4    3    5      5         6  12  13  14
# 152  ...       yes       4         2    2    3      3         8  10  10  10
# 153  ...       yes       4         5    1    1      4         0   5   0   0
# 154  ...       yes       4         2    1    1      4         0  11  11  12
# 155  ...        no       4         4    1    1      1         2  11   8   8
# 156  ...        no       2         2    3    3      5         8  16  12  13
# 157  ...        no       5         2    1    5      4         6   9   8  10
# 158  ...        no       4         2    1    2      3         2  17  15  15
# 159  ...       yes       4         5    4    4      5         4  10  12  12
# 160  ...       yes       3         3    2    2      5         0   7   6   0
# 161  ...       yes       4         4    1    4      3         6   5   9   7
# 162  ...        no       4         4    2    4      5         0   7   0   0
# 163  ...        no       5         3    1    4      2         2  10  10  10
# 164  ...       yes       5         3    1    5      5         0   5   8   7
# 165  ...        no       4         5    1    1      2        16  12  11  12
# 166  ...        no       4         3    2    4      4         4  10  10  10
# 167  ...       yes       4         2    1    1      3         0  14  15  16
# 168  ...        no       5         1    1    1      4         0   6   7   0
# 169  ...       yes       4         4    1    1      3         0  14  14  14
# 170  ...        no       3         4    2    4      2         0   6   5   0
# 171  ...       yes       4         3    1    1      3         2  13  15  16
# 172  ...        no       4         4    1    3      5         0  13  11  10
# 173  ...       yes       4         3    1    1      3         0   8   7   0
# 174  ...        no       4         4    1    1      4         4  10  11   9
# 175  ...        no       4         4    4    4      4         4  10   9   9
# 176  ...        no       3         4    1    4      5         2  13  13  11
# 177  ...        no       4         3    1    4      4         4   6   5   6
# 178  ...       yes       4         3    3    4      3        10  10   8   9
# 179  ...       yes       5         2    1    1      2         4  10  10  11
# 180  ...        no       3         4    2    3      3        10   9   8   8
# 181  ...       yes       4         2    1    2      3         2  12  13  12
# 182  ...        no       5         4    2    3      5         0  16  17  17
# 183  ...       yes       5         3    2    3      1        56   9   9   8
# 184  ...        no       1         2    1    2      1        14  12  13  12
# 185  ...       yes       4         3    2    3      4        12  12  12  11
# 186  ...       yes       3         3    1    2      3         2  11  12  11
# 187  ...       yes       4         2    1    2      5         0  15  15  15
# 188  ...       yes       3         3    1    3      3         6   8   7   9
#
# [44 rows x 25 columns]

# %% [markdown]
# 4. Выведите каждое третье наблюдение со 84 по 121 строку (по всем столбцам)

# %%
# ваш код
data.iloc[84:121:3]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 84      GP   F   15       U     GT3       T     1     1     other     other
# 87      GP   F   15       U     GT3       T     4     2     other     other
# 90      GP   F   16       U     GT3       T     3     3     other     other
# 93      GP   F   16       U     GT3       T     4     2   teacher  services
# 96      GP   M   16       R     GT3       T     4     3  services     other
# 99      GP   F   16       U     GT3       T     4     3     other   at_home
# 102     GP   M   15       U     GT3       T     4     4  services     other
# 105     GP   F   15       U     GT3       A     3     3     other    health
# 108     GP   M   15       R     GT3       T     4     4     other     other
# 111     GP   F   16       R     GT3       T     3     3  services     other
# 114     GP   M   15       R     GT3       T     2     1    health  services
# 117     GP   M   16       U     GT3       T     3     3     other  services
# 120     GP   F   15       U     GT3       T     1     2   at_home  services
#
#      ...  romantic  famrel  freetime Dalc Walc health  absences  G1  G2  G3
# 84   ...        no       4         3    2    3      4         2   9  10  10
# 87   ...        no       5         3    1    3      1         4  13  14  14
# 90   ...       yes       4         3    1    3      4         0   7   7   8
# 93   ...        no       5         3    1    1      1         0  11  10  10
# 96   ...        no       3         3    1    1      4         2  11  15  15
# 99   ...        no       5         3    1    1      3         0   7   9   8
# 102  ...        no       5         3    1    1      5         4  10  13  14
# 105  ...        no       4         3    1    1      4        10  10  11  11
# 108  ...       yes       1         3    3    5      1         6  10  13  13
# 111  ...        no       4         1    1    1      2         0   7  10  10
# 114  ...       yes       5         4    1    1      5         8   9   9   9
# 117  ...        no       5         4    1    1      5         0  13  14  13
# 120  ...        no       3         2    1    2      1         2  16  15  15
#
# [13 rows x 25 columns]

# %% [markdown]
# 5. Выведите каждое четвёртое наблюдение с 21 по 43 строку по столбцу **`age`**

# %%
# ваш код
data.loc[21:43:4, 'age']
# Out:
# 21    15
# 25    16
# 29    16
# 33    15
# 37    16
# 41    15
# Name: age, dtype: int64

# %% [markdown]
# ### Этап 3. Фильтрация

# %% [markdown]
# 1. Выведите только парней

# %%
# ваш код
cond = data['sex']=='M'
data[cond]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 5       GP   M   16       U     LE3       T     4     3  services     other
# 6       GP   M   16       U     LE3       T     2     2     other     other
# 8       GP   M   15       U     LE3       A     3     2  services     other
# 9       GP   M   15       U     GT3       T     3     4     other     other
# 12      GP   M   15       U     LE3       T     4     4    health  services
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ...  romantic  famrel  freetime Dalc Walc health  absences  G1  G2  G3
# 5    ...        no       5         4    1    2      5        10  15  15  15
# 6    ...        no       4         4    1    1      3         0  12  12  11
# 8    ...        no       4         2    1    1      1         0  16  18  19
# 9    ...        no       5         5    1    1      5         0  14  15  15
# 12   ...        no       4         3    1    3      5         2  14  14  14
# ..   ...       ...     ...       ...  ...  ...    ...       ...  ..  ..  ..
# 390  ...        no       5         5    4    5      4        11   9   9   9
# 391  ...        no       2         4    3    4      2         3  14  16  16
# 392  ...        no       5         5    3    3      3         3  10   8   7
# 393  ...        no       4         4    3    4      5         0  11  12  10
# 394  ...        no       3         2    3    3      5         5   8   9   9
#
# [187 rows x 25 columns]

# %% [markdown]
# 2. Выведите только девушек в отношениях (колонка **`romantic`**)

# %%
# ваш код
cond1 = data['sex'] == 'F'
cond2 = data['romantic']=='yes'

data[cond1 & cond2]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 40      GP   F   16       U     LE3       T     2     2     other     other
# 45      GP   F   15       U     LE3       A     4     3     other     other
# 55      GP   F   16       U     GT3       A     2     1     other     other
# 61      GP   F   16       U     GT3       T     1     1  services  services
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 370     MS   F   19       U     LE3       T     3     2  services  services
# 372     MS   F   17       U     GT3       T     2     2     other   at_home
# 376     MS   F   20       U     GT3       T     4     2    health     other
# 378     MS   F   18       U     GT3       T     3     3     other     other
# 386     MS   F   18       R     GT3       T     4     4   teacher   at_home
#
#      ...  romantic  famrel  freetime Dalc Walc health  absences  G1  G2  G3
# 3    ...       yes       3         2    1    1      5         2  15  14  15
# 40   ...       yes       3         3    1    2      3        25   7  10  11
# 45   ...       yes       5         2    1    1      5         8   8   8   6
# 55   ...       yes       5         3    1    1      2         8   8   9  10
# 61   ...       yes       5         5    5    5      5         6  10   8  11
# ..   ...       ...     ...       ...  ...  ...    ...       ...  ..  ..  ..
# 370  ...       yes       3         2    1    1      3         4   7   7   9
# 372  ...       yes       3         4    1    1      3         8  13  11  11
# 376  ...       yes       5         4    1    1      3         4  15  14  15
# 378  ...       yes       4         1    1    2      1         0  15  15  15
# 386  ...       yes       4         4    2    2      5         7   6   5   6
#
# [79 rows x 25 columns]

# %% [markdown]
# 3. Выведите студентов меньше 16 лет (включительно), которые употребляют очень много алкоголя в неделю (колонка **`Walc`**, шкала от 0 до 5, где 1 - очень мало, 5 - очень много)

# %%
# ваш код
cond1 = data['Walc'] == 5
cond2 = data['age'] <= 16

data[cond1 & cond2]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 29      GP   M   16       U     GT3       T     4     4   teacher   teacher
# 61      GP   F   16       U     GT3       T     1     1  services  services
# 66      GP   M   15       U     GT3       A     4     4     other  services
# 89      GP   M   16       U     LE3       A     4     4   teacher    health
# 100     GP   M   16       U     GT3       T     4     4  services  services
# 108     GP   M   15       R     GT3       T     4     4     other     other
# 129     GP   M   16       R     GT3       T     4     4   teacher   teacher
# 149     GP   M   15       U     LE3       A     2     1  services     other
# 151     GP   M   16       U     LE3       T     2     1   at_home     other
# 197     GP   M   16       R     LE3       T     3     3   teacher     other
# 200     GP   F   16       U     GT3       T     4     3    health     other
#
#      ...  romantic  famrel  freetime Dalc Walc health  absences  G1  G2  G3
# 29   ...       yes       4         4    5    5      5        16  10  12  11
# 61   ...       yes       5         5    5    5      5         6  10   8  11
# 66   ...       yes       1         3    5    5      3         4  13  13  12
# 89   ...        no       4         1    3    5      5        18   8   6   7
# 100  ...        no       4         5    5    5      4        14   7   7   5
# 108  ...       yes       1         3    3    5      1         6  10  13  13
# 129  ...        no       3         5    2    5      4         8  18  18  18
# 149  ...        no       4         5    2    5      5         0   8   9  10
# 151  ...       yes       4         4    3    5      5         6  12  13  14
# 197  ...        no       3         3    3    5      3         8   9   9  10
# 200  ...        no       4         3    1    5      2         2  16  16  16
#
# [11 rows x 25 columns]

# %% [markdown]
# 4. Выведите студентов, у которых оба родителя имеют высшее образование (колонки **`Medu`** и **`Fedu`** соответственно, шкала от 0 до 4, где 4 - высшее образование), но которые сами не хотят получать высшее образование (колонка **`higher`**)

# %%
# ваш код
cond1 = data['Medu']==4
cond2 = data['Fedu']==4
cond3 = data['higher']=='no'
data[cond1 & cond2 & cond3]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu     Mjob     Fjob  \
# 148     GP   M   16       U     GT3       T     4     4  teacher  teacher
#
#      ...  romantic  famrel  freetime Dalc Walc health  absences  G1  G2  G3
# 148  ...       yes       3         3    2    1      5         0   7   6   0
#
# [1 rows x 25 columns]

# %% [markdown]
# 5. Выведите студентов, которые хотят получать высшее образование, но любая из их оценок (**`G1`**, **`G2`** или **`G3`**) меньше 10

# %%
data[
    (data['higher']=='yes') & 
    ((data['G1']<10) | (data['G2']<10) | (data['G3']<10))
     ]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 7       GP   F   17       U     GT3       A     4     4     other   teacher
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 388     MS   F   18       U     LE3       T     3     1   teacher  services
# 389     MS   F   18       U     GT3       T     1     1     other     other
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ...  romantic  famrel  freetime Dalc Walc health  absences  G1  G2  G3
# 0    ...        no       4         3    1    1      3         6   5   6   6
# 1    ...        no       5         3    1    1      3         4   5   5   6
# 2    ...        no       4         3    2    3      3        10   7   8  10
# 4    ...        no       4         3    1    2      5         4   6  10  10
# 7    ...        no       4         1    1    1      1         6   6   5   6
# ..   ...       ...     ...       ...  ...  ...    ...       ...  ..  ..  ..
# 388  ...        no       4         3    1    1      1         0   7   9   8
# 389  ...        no       1         1    1    1      5         0   6   5   0
# 390  ...        no       5         5    4    5      4        11   9   9   9
# 392  ...        no       5         5    3    3      3         3  10   8   7
# 394  ...        no       3         2    3    3      5         5   8   9   9
#
# [160 rows x 25 columns]

# %% [markdown]
# ### Этап 4. Сортировка

# %% [markdown]
# 1. Отсортируйте данные по финальной оценке (**`G3`**)

# %%
# ваш код
data.sort_values('G3')
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 367     MS   F   17       R     GT3       T     1     1     other  services
# 389     MS   F   18       U     GT3       T     1     1     other     other
# 264     GP   F   18       U     GT3       T     2     2   at_home  services
# 259     GP   F   17       U     LE3       T     2     2  services  services
# 269     GP   F   18       R     GT3       T     2     1     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 113     GP   M   15       U     LE3       T     4     2   teacher     other
# 110     GP   M   15       U     LE3       A     4     4   teacher   teacher
# 374     MS   F   18       R     LE3       T     4     4     other     other
# 8       GP   M   15       U     LE3       A     3     2  services     other
# 47      GP   M   16       U     GT3       T     4     3    health  services
#
#      ...  romantic  famrel  freetime Dalc Walc health  absences  G1  G2  G3
# 367  ...       yes       5         2    1    2      1         0   7   6   0
# 389  ...        no       1         1    1    1      5         0   6   5   0
# 264  ...       yes       4         3    1    1      3         0   9  10   0
# 259  ...       yes       3         4    1    1      2         0  10   9   0
# 269  ...       yes       4         3    1    2      3         0   6   0   0
# ..   ...       ...     ...       ...  ...  ...    ...       ...  ..  ..  ..
# 113  ...        no       3         5    1    1      3        10  18  19  19
# 110  ...        no       5         5    1    1      4         6  18  19  19
# 374  ...        no       5         4    1    1      1         0  19  18  19
# 8    ...        no       4         2    1    1      1         0  16  18  19
# 47   ...        no       4         2    1    1      2         4  19  19  20
#
# [395 rows x 25 columns]

# %% [markdown]
# 2. Отсортируйте данные по финальной оценке по убыванию

# %%
# ваш код
data.sort_values('G3', ascending=False)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 47      GP   M   16       U     GT3       T     4     3    health  services
# 286     GP   F   18       U     GT3       T     2     2   at_home   at_home
# 374     MS   F   18       R     LE3       T     4     4     other     other
# 110     GP   M   15       U     LE3       A     4     4   teacher   teacher
# 8       GP   M   15       U     LE3       A     3     2  services     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 341     GP   M   18       U     GT3       T     4     4   teacher  services
# 343     GP   F   17       U     GT3       A     2     2   at_home   at_home
# 367     MS   F   17       R     GT3       T     1     1     other  services
# 389     MS   F   18       U     GT3       T     1     1     other     other
# 387     MS   F   19       R     GT3       T     2     3  services     other
#
#      ...  romantic  famrel  freetime Dalc Walc health  absences  G1  G2  G3
# 47   ...        no       4         2    1    1      2         4  19  19  20
# 286  ...        no       4         3    1    2      2         5  18  18  19
# 374  ...        no       5         4    1    1      1         0  19  18  19
# 110  ...        no       5         5    1    1      4         6  18  19  19
# 8    ...        no       4         2    1    1      1         0  16  18  19
# ..   ...       ...     ...       ...  ...  ...    ...       ...  ..  ..  ..
# 341  ...        no       4         3    2    2      2         0  10  10   0
# 343  ...       yes       3         3    1    2      4         0   9   8   0
# 367  ...       yes       5         2    1    2      1         0   7   6   0
# 389  ...        no       1         1    1    1      5         0   6   5   0
# 387  ...        no       5         4    1    2      5         0   7   5   0
#
# [395 rows x 25 columns]

# %% [markdown]
# 3. Отсортируйте данные сперва по финальной оценке (по убыванию), потом по частоте употребления алкоголя в неделю (по убыванию)

# %%
# ваш код
data.sort_values(by = ['G3', 'Walc'], ascending = [False, False])
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 47      GP   M   16       U     GT3       T     4     3    health  services
# 286     GP   F   18       U     GT3       T     2     2   at_home   at_home
# 8       GP   M   15       U     LE3       A     3     2  services     other
# 110     GP   M   15       U     LE3       A     4     4   teacher   teacher
# 113     GP   M   15       U     LE3       T     4     2   teacher     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 264     GP   F   18       U     GT3       T     2     2   at_home  services
# 332     GP   F   18       U     GT3       T     3     3  services  services
# 333     GP   F   18       U     LE3       T     2     2     other     other
# 334     GP   F   18       R     GT3       T     2     2   at_home     other
# 389     MS   F   18       U     GT3       T     1     1     other     other
#
#      ...  romantic  famrel  freetime Dalc Walc health  absences  G1  G2  G3
# 47   ...        no       4         2    1    1      2         4  19  19  20
# 286  ...        no       4         3    1    2      2         5  18  18  19
# 8    ...        no       4         2    1    1      1         0  16  18  19
# 110  ...        no       5         5    1    1      4         6  18  19  19
# 113  ...        no       3         5    1    1      3        10  18  19  19
# ..   ...       ...     ...       ...  ...  ...    ...       ...  ..  ..  ..
# 264  ...       yes       4         3    1    1      3         0   9  10   0
# 332  ...        no       5         3    1    1      4         0   7   0   0
# 333  ...       yes       4         3    1    1      2         0   8   8   0
# 334  ...        no       4         4    1    1      4         0  10   9   0
# 389  ...        no       1         1    1    1      5         0   6   5   0
#
# [395 rows x 25 columns]

# %% [markdown]
# 4. Удалите дубликаты по переменной `age`

# %%
# ваш код
data.drop_duplicates('age')
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 127     GP   F   19       U     GT3       T     0     1   at_home     other
# 247     GP   M   22       U     GT3       T     3     1  services  services
# 306     GP   M   20       U     GT3       A     3     2  services     other
# 392     MS   M   21       R     GT3       T     1     1     other     other
#
#      ...  romantic  famrel  freetime Dalc Walc health  absences  G1  G2  G3
# 0    ...        no       4         3    1    1      3         6   5   6   6
# 1    ...        no       5         3    1    1      3         4   5   5   6
# 2    ...        no       4         3    2    3      3        10   7   8  10
# 4    ...        no       4         3    1    2      5         4   6  10  10
# 127  ...        no       3         4    1    1      5         2   7   8   9
# 247  ...       yes       5         4    5    5      1        16   6   8   8
# 306  ...        no       5         5    1    1      5         0  17  18  18
# 392  ...        no       5         5    3    3      3         3  10   8   7
#
# [8 rows x 25 columns]
