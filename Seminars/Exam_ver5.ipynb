# %% [markdown]
# # Спецификация экзамена
#
# **Время:** 1.5 часа (90 минут)
#
# Вопросы разбиты на три блока:
#
# **Часть A**
# - Короткие вопросы с вариантами ответа
# - 12 вопросов по 0.3 балла
# - Всего **3.6 балла** за часть A
# - Рекомендуемое время выполнения - **30 минут**
#
# **Часть B**
# - Работа с первым набором данных
# - 4 вопроса по 0.6 баллов
# - Всего **2.4 балла** за часть B
# - Рекомендуемое время выполнения - **20 минут**
#
# **Часть С**
# - Работа со вторым набором данных
# - 8 вопросов по 0.5 баллов
# - Всего **4 балла** за часть С
# - Рекомендуемое время выполнения - **40 минут**

# %% [markdown]
# # Тренировочный вариант 5
# [Ссылка](https://edu.hse.ru/mod/quiz/view.php?id=1273745)

# %%
# сразу импортируем все библиотеки, которые нам понадобятся
import pandas as pd
import statsmodels.api as sm

# для отрисовки графиков можете использовать любую библиотеку или вообще обойтись без них
import matplotlib.pyplot as plt
import seaborn as sns

# %%
(50**2 + 50**2 + 50**2 + 100**2) / 4
# Out:
# 4375.0

# %% [markdown]
# ## Часть A

# %% [markdown]
# ### A1
# На графике изображена динамика численности популяции кроликов в некоторой области. Выберите верное утверждение.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# - Наибольшей численности популяция достигла в 1993 году.
# - С 1993 по 1994 годы численность популяции увеличилась.
# - Ни в один год численность популяции не была меньше 3.25 миллионов особей.
# - С 1991 по 1992 годы популяция увеличилась больше, чем на 1 млн особей.

# %% [markdown]
# ### A2
#
# Соотнесите тип визуализации и признак.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# | Описание | Тип графика |
# | -------- | ----------- |
# | Распределение стоимости одной ночи в отеле ($) | Столбчатая диаграмма |
# | Зависимость общего рейтинга отеля (0-10) от стоимости одной ночи в нем ($) | Диаграмма рассеяния |
# | Среднее значение рейтинга (0-10) по категориям: сервис, удобства, расположение, чистота | Круговая диаграмма |
# | Распределение количества отелей по звёздности (1-5) | Ящик с усами |

# %% [markdown]
# ### A3
# Аналитик Евгения занимается исследованием моделей автомобилей. Определите тип переменных, с которыми она работает.

# %% [markdown]
# | **Признак** | **Тип переменной** |
# | ------- | -------------- |
# | Марка автомобиля | Категориальная бинарная |
# | Количество мест в автомобиле | Количественная дискретная |
# | Наличие дизельного двигателя | Категориальная номинальная |
# | Класс автомобиля (эконом, комфорт, бизнес, люкс) | Количественная непрерывная |
# | Вес автомобиля (кг) | Категориальная порядковая |

# %% [markdown]
# ### A4
# Какую меру измерения центральной тенденции можно использовать при работе с категориальными переменными, которые не закодированы числами

# %% [markdown]
# Выберите один ответ:
# - Медиана
# - Размах
# - Мода
# - Арифметическое среднее

# %% [markdown]
# ### A5
# Внизу представлены гистограммы для четырёх величин. Выберите величину, у которой дисперсия наименьшая.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# - A
# - B
# - C
# - D

# %% [markdown]
# ### A6
# Были собраны данные об уровне заряда на телефоне (от 0 до 100%) пользователей к концу дня. Ниже представлена визуализация данного признака. Отметьте верное утверждение.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# - К концу дня у 50% пользователей заряд на телефоне более 53%.
# - К концу дня у 50% пользователей заряд на телефоне от 53% до 69%.
# - Нет такого пользователя, у которого к концу дня сохраняется максимальный заряд (100%).
# - К концу дня у 80% пользователей заряд на телефоне менее 75%

# %% [markdown]
# ### A7
# Алена занимается изучением флоры заповедников Казахстана. Какая из выборок будет наиболее репрезентативной?

# %% [markdown]
# - Информация о флоре в случайных заповедниках Казахстана
# - Информация о распространении цветка Белой кувшинки по территории Казахстана
# - Информация о флоре, собранная в крупнейшем заповеднике Казахстана (Коргалжынский заповедник)
# - Информация о флоре, собранная в городских парках Казахстана

# %% [markdown]
# ### A8
# Укажите, между какими признаками значение коэффициента корреляции ближе всего к 0.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# - A
# - B
# - C
# - D

# %% [markdown]
# ### A9
# Аналитик Алла исследует зависимость между количеством осадков в городах и расстоянием до океана (км).  Оказалось, что выборочный коэффициент корреляции между этими величинами, полученный на некоторой выборке, равен -0.7. Выберите верное утверждение.

# %% [markdown]
# - Существует обратная линейная зависимость между расстоянием до океана и количеством осадков.
# - Не существует линейной зависимости между расстоянием до океана и количеством осадков.
# - Расстояние до океана влияет на количество осадков в городе.
# - При увеличении расстояния до океана количество осадков в городах также увеличивается.

# %% [markdown]
# ### A10
# Механик Игорь изучает как объем двигателя ($\text{Двигатель}$) влияет на количество лошадиных сил в автомобиле ($\text{Лошадиные силы}$):
#
# $$\text{Лошадиные силы} = w_1 \cdot \text{Двигатель} + w_0$$
#
# Соотнесите термины регрессии и составляющие модели:

# %% [markdown]
# | Составляющая модели | Термин регрессии |
# | ------------------- | ---------------- |
# | $w_0$ | Предикторы / Независимые переменные |
# | **Объем двигателя** | Целевая переменная / Зависимая переменная |
# | **Автомобиль** | Наблюдение |
# | **Лошадиные силы** | Коэффициенты перед предикторами |
# | $w_1$ | Свободный коэффициент / константа |

# %% [markdown]
# ### A11
# Была построена модель, которая предсказывает, как некоторый признак X влияет на признак Y. На графике изображена получившаяся модель (красным) и реальные данные (синим). Укажите, чему равно MAE (средняя абсолютная ошибка) модели.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# - 31.75
# - 23.50
# - 70.00
# - 62.50

# %% [markdown]
# ### A12
# Исследовательница Диана собирала данные о переменных $Y$, $X$ и $Z$. После этого она оценила следующую линейную регрессию:
# $$Y_i = 0 - 0.25 \cdot X_i - 0.75 \cdot Z_i $$
# где $Y_i$, $X_i$ и $Z_i$ - значения переменных $Y$, $X$ и $Z$ для наблюдения $i$
#
# Выберите верное утверждение об интерпретации этой линейной модели.

# %% [markdown]
# - Если $X$ увеличится на 1, то $Y$ увеличится на 0.25.
# - Признак $Z$ оказывает наибольшее влияние на признак $Y$.
# - Если $X$ увеличится на 1, то $Z$ увеличится на 0.75.
# - Если $Z$ увеличится на 2, то $Y$ увеличится на 1.5.

# %% [markdown]
# ---

# %% [markdown]
# ## Часть B

# %% [markdown]
# Для выполнения заданий **Части B** выберите файл, с которым вам будет удобнее работать, и загрузите его на компьютер (файлы идентичны по содержанию). Для того, чтобы загрузить файл, нажмите правой кнопкой мыши на ссылку и выберите "Сохранить файл по ссылке..." или "Открыть ссылку в новой вкладке..."
#
# - [train5_b.csv](https://edu.hse.ru/pluginfile.php/3446676/question/questiontext/7165899/13/12361126/train5_b.csv)
# - [train5_b.xlsx](https://edu.hse.ru/pluginfile.php/3446676/question/questiontext/7165899/13/12361126/train5_b.xlsx)

# %% [markdown]
# Во всех заданиях Части B вам предстоит работать с датасетом, который содержит информацию об условиях, в которых росли растения.
# Датасет содержит следующие признаки:
#
# - **Soil_Type** - тип почвы (1 — глина, 2 — суглинок, 3 — песок)
# - **Sunlight_Hours** - среднее количество часов, которое растение проводило на солнце
# - **Temperature** - температура воздуха, в которой росли растения (градусы Цельсия)
# - **Humidity** - относительная влажность воздуха, в которой росли растения (%)

# %%
import pandas as pd

# %%
data_b = pd.read_csv("train5_b.csv")
data_b.head()
# Out:
#    Soil_Type  Sunlight_Hours  Temperature   Humidity
# 0          2        5.192294    31.719602  61.591861
# 1          3        4.033133    28.919484  52.422276
# 2          2        8.892769    23.179059  44.660539
# 3          2        8.241144    18.465886  46.433227
# 4          3        8.374043    18.128741  63.625923

# %% [markdown]
# ### B1 (13)

# %% [markdown]
# Какой из графиков визуализирует влажность воздуха (**Humidity**)?
#
# ![image.png](attachment:image.png)

# %%
data_b['Humidity'].plot(kind='box', vert=False)
# Out:
# <Axes: >

# %%
data_b['Soil_Type'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ### B2 (14)
#
# Постройте график, показывающий зависимость признака **Temperature** и **Humidity**. На основе графика укажите все **неверные** утверждения (MCQ):

# %% [markdown]
# - Меньшая часть растений росла при влажности воздуха не более 40%.
# - Большая часть растений росла при температуре менее 25 $С^0$ и во влажности более 60%.
# - Нет такого растения, которое росло при влажности воздуха более 15%.
# - Между влажностью воздуха и температурой существует положительная взаимосвязь.

# %%
data_b.plot('Humidity', 'Temperature', kind='scatter');

# %%
import matplotlib.pyplot as plt

plt.scatter(x = data_b['Humidity'], y = data_b['Temperature'])

# %%
import seaborn as sns

sns.scatterplot(data=data_b, x = 'Temperature', y = 'Humidity');

# %% [markdown]
# ### B3 (15)
# Рассчитайте интерпретируемую меру центральной тенденции для признака **Soil_Type**. Ответ округлите до двух знаков.
#
# Пример ответа: 100.00

# %%
data_b['Soil_Type'].mode().item()
# Out:
# 1

# %%
data_b['Soil_Type'].value_counts()
# Out:
# Soil_Type
# 1    67
# 3    64
# 2    62
# Name: count, dtype: int64

# %% [markdown]
# ### B4 (16)
# Среди признаков **Soil_Type**, **Sunlight_Hours** и **Temperature** выберите те, между которыми можно рассчитать интерпретируемый коэффициент корреляции Пирсона. В ответ запишите найденное значение корреляции. Ответ округлите до двух знаков.
#
# Пример ответа: 0.99

# %%
data_b.corr(numeric_only=True)   #.loc['Sunlight_Hours', 'Temperature']
# Out:
#                 Soil_Type  Sunlight_Hours  Temperature  Humidity
# Soil_Type        1.000000       -0.134088    -0.013128 -0.031696
# Sunlight_Hours  -0.134088        1.000000    -0.100628 -0.052482
# Temperature     -0.013128       -0.100628     1.000000  0.117648
# Humidity        -0.031696       -0.052482     0.117648  1.000000

# %% [markdown]
# ---

# %% [markdown]
# ## Часть C

# %% [markdown]
# Для выполнения заданий **Части C** выберите файл, с которым вам будет удобнее работать, и загрузите его на компьютер (файлы идентичны по содержанию). Для того, чтобы загрузить файл, нажмите правой кнопкой мыши на ссылку и выберите "Сохранить файл по ссылке..." или "Открыть ссылку в новой вкладке..."
# - [train5_C.csv](https://edu.hse.ru/pluginfile.php/3446676/question/questiontext/7165899/18/12421678/train5_C.csv)
# - [train5_C.xlsx](https://edu.hse.ru/pluginfile.php/3446676/question/questiontext/7165899/18/12421678/train5_C.xlsx)

# %% [markdown]
# Во всех заданиях Части C вам предстоит работать с датасетом, который содержит информацию о горнолыжных курортах.
#
# Датасет содержит следующие признаки:
# - **Resort** - название курорта
# - **Country** - страна, в которой находится курорт
# - **HighestPoint** - самый высокий пик (метры над уровнем моря)
# - **LowestPoint** - самый низкий пик (метры над уровнем моря)
# - **DayPassPriceAdult** - цена билета на подъемник (€)
# - **TotalSlope** - количество трасс
# - **NightSki** - наличие ночной подсветки трасс (есть — Yes, нет — No)
# - **TotalLifts** - количество подъемников
# - **LiftCapacity** - общая вместимость подъемников (чел.)

# %% [markdown]
# ### C1 (17)
# Для страны (**Country**), где больше всего горнолыжных курортов, найдите название курорта (**Resort**), с наименьшей высотой пика по признаку **HighestPoint**.
#
# Пример ответа: Alpendorf (Ski amedé)

# %% [markdown]
# ### C2 (18)
# Найдите значение интерквартильного диапазона признака **LiftCapacity** для горнолыжных курортов, имеющих ночную подсветку трасс (Yes; **NightSki**). Ответ округлите до двух знаков.
#
# Пример ответа: 100.00

# %% [markdown]
# ### C3 (19)
# Постройте сводную таблицу, где по строкам располагаются страны (**Country**), а по столбцам — среднее по признаку **HighestPoint** и **LowestPoint** для каждой страны. В качестве ответа укажите название страны, для которой модуль разности между средним значением **HighestPoint** и **LowestPoint** наибольший.
#
# Пример ответа: Austria

# %% [markdown]
# ### C4 (20)
# Добавьте в таблицу новый признак `coded`, который будет представлять собой кодированные значения признака **Country**. Кодировку проведите следующим образом: если значение **Country** содержит строку **Russia** – 1, иначе – 0. В ответ введите сумму по признаку `coded`. Ответ округлите до двух знаков.
#
# Пример ответа: 100.00

# %% [markdown]
# ### C5 (21)
# Будем считать, что выбросами считаются наблюдения, которые отличаются от среднего арифметического на 2 стандартных отклонения и более. Определите, сколько наблюдений считаются выбросами по признаку **TotalLifts**. Ответ округлите до двух знаков.
#
# Пример ответа: 100.00

# %% [markdown]
# ### C6 (22)
# Постройте корреляционную матрицу. Найдите переменную, которая имеет самую слабую корреляцию с переменной **LiftCapacity**. Признак `coded` учитывать не нужно. В ответ впишите модуль полученного значения корреляции. Ответ округлите до двух знаков.
#
# Пример ответа: 0.99

# %% [markdown]
# ### C7 (23)
# Постройте модель линейной регрессии, которая показывает, как количество трасс на горнолыжном курорте (**TotalSlope**) влияет на стоимость билета на подъемник (**DayPassPriceAdult**). В качестве ответа укажите значение коэффициента перед независимой переменной. Ответ округлите до двух знаков.
#
# Пример ответа: 0.00

# %% [markdown]
# ### C8 (24)
# Постройте модель линейной регрессии, которая показывает, как количество трасс на горнолыжном курорте (**TotalSlope**) влияет на стоимость билета на подъемник (**DayPassPriceAdult**). В качестве ответа укажите среднюю абсолютную ошибку (MAE) модели. Ответ округлите до двух знаков.
#
# Пример ответа: 0.00
